# %% [markdown]
# <a href="https://colab.research.google.com/github/kishon45229/Customer-Churn-Prediction-in-Telecom-Industry/blob/main/Understanding_of_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Customer Churn Prediction in Telecom Industry**

# %% [markdown]
# In the Customer Churn Prediction in the Telecom Industry project, I focused on thoroughly understanding the dataset to build a strong foundation for analysis. I began by examining the structure, types of variables, and basic statistical summaries, which helped identify key features and detect any immediate issues. To gain further insights, I calculated summarization statistics to understand the central tendencies, variability, and distribution patterns of both numerical and categorical variables. Visual exploration included creating histograms for numerical features to observe distribution patterns, count plots for categorical variables to assess category frequencies, and a correlation matrix with a heatmap to uncover relationships between variables. Additionally, I identified potential data problems such as missing values, outliers, and duplicate records, addressing them to ensure a clean and reliable dataset for accurate churn prediction modeling.
#
# ITBIN-2110-0063
#
# M.J.F.Mulhima

# %% [markdown]
# # **Get an initial understanding of data**

# %% [markdown]
# Import necessery libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Add dataset and get an initial understanding**

# %% [markdown]
# As a first step, the below code `pd.read_csv()` reads a CSV file into a pandas DataFrame. and get a some idea about the data.

# %%
datafile = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/WA_Fn-UseC_-Telco-Customer-Churn.csv')
datafile
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# show the info about data using `datafile.info()`.

# %%
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
datafile['TotalCharges'] = pd.to_numeric(datafile['TotalCharges'], errors='coerce')
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## **Calculate basic summarization statistics**

# %% [markdown]
# See the summery of all the numerical dataset in the datafile using `datafile.describe()`.

# %%
numerical_summary = datafile.describe()
numerical_summary
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# See the summery of all the datatype of object in the dataset using `datafile.describe(include=['object')`.

# %%
categorical_summary = datafile.describe(include=['object'])
categorical_summary
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %% [markdown]
# # **Visualize the data**

# %% [markdown]
# We will create histograms, box plots, and a correlation heatmap to visualize the data.

# %% [markdown]
# ## **Histogram of All Columns**

# %% [markdown]
# We visualized the numerical data using histogram.

# %%
datafile.hist(figsize=(15, 10))
plt.show()

# %% [markdown]
# ## **Box Plot for Each Categorical Column**

# %% [markdown]
# ### **This is formatted as code**

# %% [markdown]
# We visualized the numerical data in the box plot.

# %%
for column in datafile.drop(columns='customerID').select_dtypes(include=['object']).columns:
    plt.figure(figsize=(10, 5))
    sns.boxplot(data=datafile, y=column)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# ## **Correlation Heatmap for Numerical Columns**

# %% [markdown]
# We can generate a heatmap for this correlation values.

# %%
correlation_matrix = datafile.select_dtypes(include=['int64', 'float64']).corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %% [markdown]
# If the corr is,
#
# 0 <= corr <= 0.19 - Very low correlation
#
# 0.2 <= corr <= 0.39 - Low correlation
#
# 0.4 <= corr <= 0.59 - Moderate
#
# 0.6 <= corr <= 0.79 - High correlation.
#
# 0.8 <= corr <= 1.0 - Very high correlation.

# %% [markdown]
# ## **Identify data problems - such as outliers, missing data, and duplicate records**

# %%
missing_values = datafile.isnull().sum()
missing_values
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
duplicate_records = datafile.duplicated().sum()
duplicate_records
# Out:
# 0

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In the Customer Churn Prediction in the Telecom Industry project, I conducted a comprehensive data understanding process to ensure the dataset was well-prepared for analysis. By thoroughly exploring the data, calculating summarization statistics, and visualizing key features, I was able to identify and address potential data problems, such as missing values, outliers, and duplicates. These steps laid a solid foundation for subsequent modeling efforts, ensuring that the data was reliable and ready for effective churn prediction, ultimately enabling deeper insights into customer behavior and trends.

# %% [markdown]
# # **Next Steps in Data Preprocessing-(Part 1)**

# %% [markdown]
# - **Cleaning**: Remove inconsistencies by eliminating incorrect/incomplete data, applying binning, regression, and clustering techniques, and handling missing values using median, mean, or mode.
#
# - **Reduction**: Implement dimensionality reduction to improve computational efficiency and model performance.
